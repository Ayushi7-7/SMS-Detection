# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('spam.csv', encoding='latin-1')

# %%
df.sample(5)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 3792   ham            Hey are you angry with me. Reply me dr.        NaN
# 5472   ham  Well obviously not because all the people in m...        NaN
# 1017   ham             Shall i send that exe to your mail id.        NaN
# 2401  spam  Babe: U want me dont u baby! Im nasty and have...        NaN
# 2527   ham  Mmmmm ... I loved waking to your words this mo...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 3792        NaN        NaN
# 5472        NaN        NaN
# 1017        NaN        NaN
# 2401        NaN        NaN
# 2527        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
#data cleaning
#eda
#text preprocessing
#model buliding
#evaluation
#improvement
#website
#deploy

# %%
1
# Out:
# 1

# %%
## 1.Data cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
#drop last 3 columns
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 5549  ham  You know, wot people wear. T shirts, jumpers, ...
# 5349  ham                                        I'm home...
# 2804  ham                   I think it's all still in my car
# 1842  ham                      \Are you comingdown later?\""
# 2334  ham                          Do you like Italian food?

# %%
#renaming the column
df.rename(columns={'v1':'target','v2':'text'},inplace=True)
df.sample(5)
# Out:
#      target                                               text
# 1416    ham            No..few hours before.went to hair cut .
# 4585   spam  Mila, age23, blonde, new in UK. I look sex wit...
# 3765    ham                            Yes.mum lookin strong:)
# 3542    ham           I'm e person who's doing e sms survey...
# 0       ham  Go until jurong point, crazy.. Available only ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
#missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
#check for duplicate values
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
#remove duplicates
df = df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (5169, 2)

# %%
#2.EDA

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(), labels=['ham','spam'],autopct="%0.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x283b44d2b50>,
# ...
#  [Text(-1.014499732282844, 0.4251944181172162, 'ham'),
#   Text(1.0144998708287172, -0.42519408755122207, 'spam')],
#  [Text(-0.5533634903360967, 0.2319242280639361, '87.37'),
#   Text(0.553363565906573, -0.231924047755212, '12.63')])

# %%
df['num_characters'] = df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
#num of words
import re

df['num_words'] = df['text'].apply(lambda x: len(re.findall(r'\b\w+\b', x)))
df['num_sentences'] = df['text'].apply(
    lambda x: max(1, len(re.findall(r'[.!?]+', x)))
)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         20              3
# 1          6              2
# 2         33              1
# 3         11              2
# 4         14              1

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    15.989940       2.043529
# std         58.236293    11.518372       1.574099
# min          2.000000     0.000000       1.000000
# 25%         36.000000     8.000000       1.000000
# 50%         60.000000    12.000000       2.000000
# 75%        117.000000    23.000000       3.000000
# max        910.000000   190.000000      39.000000

# %%
#ham messages
df[df['target']==0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    14.600974       1.904783
# std         56.358207    11.448193       1.508856
# min          2.000000     0.000000       1.000000
# 25%         34.000000     7.000000       1.000000
# 50%         52.000000    11.000000       1.000000
# 75%         90.000000    19.000000       2.000000
# max        910.000000   190.000000      39.000000

# %%
#spam messages
df[df['target']==1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   25.595712       3.003063
# std         30.137753    6.185684       1.678990
# min         13.000000    2.000000       1.000000
# 25%        132.000000   24.000000       2.000000
# 50%        149.000000   27.000000       3.000000
# 75%        157.000000   29.000000       4.000000
# max        224.000000   40.000000       9.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target']==0]['num_characters'])
sns.histplot(df[df['target']==1]['num_characters'],color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize=(12,8))
sns.histplot(df[df['target']==0]['num_words'])
sns.histplot(df[df['target']==1]['num_words'],color='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True)
# Out:
# <Axes: >

# %%
import snowballstemmer

# %%
import sys
# !{sys.executable} -m pip install snowballstemmer
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: C:\Users\DELL\cryenv\Scripts\python.exe -m pip install --upgrade pip

# %%
import re
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import snowballstemmer

stemmer = snowballstemmer.stemmer('english')

def transform_text(text):
    text = text.lower()
    tokens = re.findall(r'\b\w+\b', text)
    tokens = [
        stemmer.stemWord(w)
        for w in tokens
        if w not in ENGLISH_STOP_WORDS
    ]
    return tokens

# %%
transform_text('hi how are %% you Ayuhsi so loved')
# Out:
# ['hi', 'ayuhsi', 'love']

# %%
#data preprocessisng 
#lower case
#tokenization
#removing speical characters
#remove stop words and punctuations
#stemming

# %%
df['text'][0]
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %%
df['transformed_text']=df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         20              3  [jurong, point, crazi, avail, bugi, n, great, ...
# 1          6              2                       [ok, lar, joke, wif, u, oni]
# 2         33              1  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3         11              2               [u, dun, say, earli, hor, u, c, say]
# 4         14              1               [nah, don, t, think, goe, usf, live]

# %%
#word cloud module
import sys
# !{sys.executable} -m pip install wordcloud
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: C:\Users\DELL\cryenv\Scripts\python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
df['transformed_text_str'] = df['transformed_text'].apply(lambda x: " ".join(x))

spam_wc = wc.generate(
    df[df['target'] == 1]['transformed_text_str'].str.cat(sep=" ")
)

# %%
plt.figure(figsize=(12,6))
plt.imshow(spam_wc)

# %%
df['transformed_text_str'] = df['transformed_text'].apply(lambda x: " ".join(x))

ham_wc = wc.generate(
    df[df['target'] == 0]['transformed_text_str'].str.cat(sep=" ")
)

# %%
plt.figure(figsize=(12,6))
plt.imshow(ham_wc)

# %%
#top 30 words 
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences  \
# 0         20              3
# 1          6              2
# 2         33              1
# 3         11              2
# 4         14              1
#
#                                     transformed_text  \
# 0  [jurong, point, crazi, avail, bugi, n, great, ...
# 1                       [ok, lar, joke, wif, u, oni]
# 2  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3               [u, dun, say, earli, hor, u, c, say]
# 4               [nah, don, t, think, goe, usf, live]
#
# ...

# %%
spam_corpus = []

for msg in df[df['target'] == 1]['transformed_text']:
    for word in msg:
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 11402

# %%
from collections import Counter
sns.barplot(pd.DataFrame(Counter(spam_corpus).most_common(30))[0],),pd.DataFrame(Counter(spam_corpus).most_common(30))[1],
plt.xtixks(rotation='vertical')
plt.show #top 30 words used in the spam messages
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[230], line 3
#       1 from collections import Counter
#       2 sns.barplot(pd.DataFrame(Counter(spam_corpus).most_common(30))[0],),pd.DataFrame(Counter(spam_corpus).most_common(30))[1],
# ----> 3 plt.xtixks(rotation='vertical')
#       4 plt.show #top 30 words used in the spam messages
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xtixks'

# %%
ham_corpus = [] #ham model

for msg in df[df['target'] == 0]['transformed_text']:
    for word in msg:
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 34958

# %%
#model building naive bayes as it works best on textual data so we use this model

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=3000)

# %%
df['transformed_text_str'] = df['transformed_text'].apply(lambda x: " ".join(x))

cv = CountVectorizer(max_features=3000)
X = cv.fit_transform(df['transformed_text_str']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y=df['target'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0], shape=(5169,))

# %%
#train test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2
)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB

# %%
gnb.fit(X_train,y_train)
y_pred1=gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1)) #high precsion model as we wnat to reduce the true positives
# Out:
# 0.8733075435203095
# [[782 114]
#  [ 17 121]]
# 0.5148936170212766

# %%
mnb.fit(X_train,y_train)
y_pred2=mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9816247582205029
# [[888   8]
#  [ 11 127]]
# 0.9407407407407408

# %%
import numpy as np
bnb_model=BernoulliNB()
bnb_model.fit(X_train, y_train)

y_pred3 = bnb_model.predict(X_test)

print(accuracy_score(y_test, y_pred3))
print(confusion_matrix(y_test, y_pred3))
print(precision_score(y_test, y_pred3))
# Out:
# 0.9854932301740812
# [[894   2]
#  [ 13 125]]
# 0.984251968503937

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer()

# %%
df['transformed_text_str'] = df['transformed_text'].apply(lambda x: " ".join(x))

tfidf= TfidfVectorizer(max_features=3000)
X =tfidf.fit_transform(df['transformed_text_str']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y=df['target'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0], shape=(5169,))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2
)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB

# %%
gnb.fit(X_train,y_train)
y_pred1=gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8713733075435203
# [[782 114]
#  [ 19 119]]
# 0.5107296137339056

# %%
mnb.fit(X_train,y_train)
y_pred2=mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.97678916827853
# [[896   0]
#  [ 24 114]]
# 1.0

# %%
import numpy as np
bnb_model=BernoulliNB()
bnb_model.fit(X_train, y_train)

y_pred3 = bnb_model.predict(X_test)

print(accuracy_score(y_test, y_pred3))
print(confusion_matrix(y_test, y_pred3))
print(precision_score(y_test, y_pred3))
# Out:
# 0.9854932301740812
# [[894   2]
#  [ 13 125]]
# 0.984251968503937

# %%
#tfidf mnb is choosen over cv because accuracy do not matter a lot here as the data is imbalanced so precison is more important

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
#from xgboost import XGBClassifier

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier (max_depth=5)
lrc = LogisticRegression (solver='liblinear', penalty='l2',max_iter=3000)
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators =50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50, random_state=2)
#xgb = XGBClassifier(n_estimators=50, random_state=2)

# %%
clfs = {
'SVC': svc,
'KN': knc,
'NB': mnb,
'DT': dtc,
'LR': lrc,
'RF': rfc,
'AdaBoost':abc,
'BgC': bc,
'ETC': etc,
'GBDT':gbdt,
#'xgb':xgb
}

# %%
def train_classifier(clf, X_train, y_train, X_test,y_test):
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score (y_test,y_pred)
    return accuracy, precision

# %%
train_classifier(svc,X_train,y_train,X_test,y_test)
# Out:
# (0.9777562862669246, 0.9752066115702479)

# %%
accuracy_scores = []
precision_scores = []
for name, clf in clfs.items():
    current_accuracy, current_precision = train_classifier(clf, X_train, y_train, X_test,y_test)
    print("For ", name)
    print("Accuracy", current_accuracy)
    print("Precision", current_precision)
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy 0.9777562862669246
# Precision 0.9752066115702479
# For  KN
# Accuracy 0.9052224371373307
# Precision 1.0
# For  NB
# Accuracy 0.97678916827853
# Precision 1.0
# For  DT
# Accuracy 0.9264990328820116
# Precision 0.8974358974358975
# For  LR
# Accuracy 0.9661508704061895
# Precision 0.9904761904761905
# For  RF
# Accuracy 0.97678916827853
# Precision 0.975
# For  AdaBoost
# Accuracy 0.8945841392649904
# Precision 0.8918918918918919
# For  BgC
# Accuracy 0.9690522243713733
# Precision 0.9206349206349206
# For  ETC
# Accuracy 0.9825918762088974
# Precision 0.9761904761904762
# For  GBDT
# Accuracy 0.9497098646034816
# Precision 1.0

# %%
performance_df = pd.DataFrame({'Algorithm': clfs.keys(), 'Accuracy': accuracy_scores, 'Precision': precision_scores}).sort_values('Precision', ascending=False)

# %%
performance_df
# Out:
#   Algorithm  Accuracy  Precision
# 1        KN  0.905222   1.000000
# 2        NB  0.976789   1.000000
# 9      GBDT  0.949710   1.000000
# 4        LR  0.966151   0.990476
# 8       ETC  0.982592   0.976190
# 0       SVC  0.977756   0.975207
# 5        RF  0.976789   0.975000
# 7       BgC  0.969052   0.920635
# 3        DT  0.926499   0.897436
# 6  AdaBoost  0.894584   0.891892

# %%
performance_df1 = pd.melt(performance_df, id_vars="Algorithm")

# %%
performance_df1
# Out:
#    Algorithm   variable     value
# 0         KN   Accuracy  0.905222
# 1         NB   Accuracy  0.976789
# 2       GBDT   Accuracy  0.949710
# 3         LR   Accuracy  0.966151
# 4        ETC   Accuracy  0.982592
# 5        SVC   Accuracy  0.977756
# 6         RF   Accuracy  0.976789
# 7        BgC   Accuracy  0.969052
# 8         DT   Accuracy  0.926499
# 9   AdaBoost   Accuracy  0.894584
# 10        KN  Precision  1.000000
# 11        NB  Precision  1.000000
# 12      GBDT  Precision  1.000000
# 13        LR  Precision  0.990476
# 14       ETC  Precision  0.976190
# 15       SVC  Precision  0.975207
# 16        RF  Precision  0.975000
# 17       BgC  Precision  0.920635
# 18        DT  Precision  0.897436
# 19  AdaBoost  Precision  0.891892

# %%
sns.catplot(
    x='Algorithm',
    y='value',
    hue='variable',
    data=performance_df1,   # ✅ no quotes
    kind='bar',
    height=5
)

plt.ylim(0.5, 1.0)
plt.xticks(rotation='vertical')
plt.show()

# %%
#model improve!
#1. change the ma_feature parameter of tfidf

# %%
temp_df =pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_max_ft_3000':accuracy_scores,'Precision_max_features':precision_scores})

# %%
performance_df.merge(temp_df,on='Algorithm')
# Out:
#   Algorithm  Accuracy  Precision  Accuracy_max_ft_3000  Precision_max_features
# 0        KN  0.905222   1.000000              0.905222                1.000000
# 1        NB  0.976789   1.000000              0.976789                1.000000
# 2      GBDT  0.949710   1.000000              0.949710                1.000000
# 3        LR  0.966151   0.990476              0.966151                0.990476
# 4       ETC  0.982592   0.976190              0.982592                0.976190
# 5       SVC  0.977756   0.975207              0.977756                0.975207
# 6        RF  0.976789   0.975000              0.976789                0.975000
# 7       BgC  0.969052   0.920635              0.969052                0.920635
# 8        DT  0.926499   0.897436              0.926499                0.897436
# 9  AdaBoost  0.894584   0.891892              0.894584                0.891892

# %%
#scaling do not improvethe datat as much and reduces the precision

# %%
#voting classifier
svc=SVC(kernel='sigmoid',gamma=1.0,probability=True)
mnb=MultinomialNB()
etc=ExtraTreesClassifier(n_estimators=50,random_state=2)

from sklearn.ensemble import VotingClassifier

# %%
voting=VotingClassifier(estimators=[('svm',svc),('nb',mnb),('et',etc)],voting='soft')

# %%
voting.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('svm',
#                               SVC(gamma=1.0, kernel='sigmoid',
#                                   probability=True)),
#                              ('nb', MultinomialNB()),
#                              ('et',
#                               ExtraTreesClassifier(n_estimators=50,
#                                                    random_state=2))],
#                  voting='soft')

# %%
y_pred =voting.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.9835589941972921
# Precision 0.991869918699187

# %%
#applying stacking

# %%
estimators = [
    ('svm', SVC(kernel='linear', probability=True)),
    ('nb', MultinomialNB()),
    ('et', ExtraTreesClassifier(n_estimators=100, random_state=42))
]
final_estimator = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

# %%
from sklearn.ensemble import StackingClassifier

# %%
clf = StackingClassifier(estimators=estimators,final_estimator=final_estimator)

# %%
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.9825918762088974
# Precision 0.9477611940298507

# %%
#whenever we got asms steps are 
#1. text transformation 
#2.vectorize
#3.Algorithm apply

# %%
# import pickle
# pickle.dump(tfidf,open('vectorizer.pkl','wb'))
# pickle.dump(mnb,open('model.pkl','wb'))

# %%
from sklearn.naive_bayes import MultinomialNB

mnb = MultinomialNB()
mnb.fit(X_train, y_train)   # ✅ REQUIRED
# Out:
# MultinomialNB()

# %%
msg = "Congratulations! you have won a lottery"

vec = tfidf.transform([msg])

prediction = mnb.predict(vec)

print(prediction)
# Out:
# [0]

# %%
msg = "Hey, are we meeting today?"

vec = tfidf.transform([msg])
prediction = mnb.predict(vec)

print(prediction)
# Out:
# [0]

# %%
msg = "WIN cash now!!! Claim your prize"

vec = tfidf.transform([msg])
prediction = mnb.predict(vec)

print(prediction)
# Out:
# [1]

# %%
msgs = [
    "Hello, how are you?",
    "Congratulations! You won a lottery"
]

vec = tfidf.transform(msgs)
prediction = mnb.predict(vec)

print(prediction)
# Out:
# [0 0]

# %%
msgs = "Please review the document I shared"

vec = tfidf.transform([msgs])
prediction = mnb.predict(vec)

print(prediction)
# Out:
# [0]
